# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country, "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | luwuk
# Processing Record 4 of Set 1 | vardo
# Processing Record 5 of Set 1 | taksimo
# Processing Record 6 of Set 1 | bambous virieux
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | sioux lookout
# Processing Record 11 of Set 1 | port elizabeth
# Processing Record 12 of Set 1 | mount gambier
# Processing Record 13 of Set 1 | manado
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | lichinga
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | plettenberg bay
# Processing Record 18 of Set 1 | talcher
# Processing Record 19 of Set 1 | meulaboh
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | esperance
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | uklana mandi
# Processing Record 24 of Set 1 | tuatapere
# Processing Record 25 of Set 1 | port macquarie
# Processing Record 26 of Set 1 | damaturu
# Processing Record 27 of Set 1 | jumla
# Processing Record 28 of Set 1 | moundou
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | saint george
# Processing Record 31 of Set 1 | qitaihe
# Processing Record 32 of Set 1 | yining
# Processing Record 33 of Set 1 | faanui
# Processing Record 34 of Set 1 | kloulklubed
# Processing Record 35 of Set 1 | lebu
# Processing Record 36 of Set 1 | asfi
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 1 | provideniya
# Processing Record 41 of Set 1 | coihaique
# Processing Record 42 of Set 1 | port hardy
# Processing Record 43 of Set 1 | aykhal
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | baykit
# Processing Record 50 of Set 1 | caravelas
# Processing Record 1 of Set 2 | grindavik
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | severnyy
# Processing Record 4 of Set 2 | markivka
# Processing Record 5 of Set 2 | umm lajj
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | te anau
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | gravdal
# Processing Record 11 of Set 2 | richards bay
# Processing Record 12 of Set 2 | sehithwa
# Processing Record 13 of Set 2 | lavrentiya
# Processing Record 14 of Set 2 | tungkang
# City not found. Skipping...
# Processing Record 15 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 2 | maragogi
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | bushehr
# Processing Record 19 of Set 2 | beringovskiy
# Processing Record 20 of Set 2 | geraldton
# Processing Record 21 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 2 | cherskiy
# Processing Record 23 of Set 2 | sozimskiy
# Processing Record 24 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 2 | kaitangata
# Processing Record 26 of Set 2 | portland
# Processing Record 27 of Set 2 | vaini
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | kruisfontein
# Processing Record 30 of Set 2 | port lincoln
# Processing Record 31 of Set 2 | charagua
# Processing Record 32 of Set 2 | torbay
# Processing Record 33 of Set 2 | oparino
# Processing Record 34 of Set 2 | nanortalik
# Processing Record 35 of Set 2 | ortona
# Processing Record 36 of Set 2 | gazanjyk
# Processing Record 37 of Set 2 | berlevag
# Processing Record 38 of Set 2 | chamba
# Processing Record 39 of Set 2 | tilichiki
# Processing Record 40 of Set 2 | rawatsar
# Processing Record 41 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 2 | busselton
# Processing Record 43 of Set 2 | klaksvik
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 2 | goderich
# Processing Record 47 of Set 2 | maniitsoq
# Processing Record 48 of Set 2 | flinders
# Processing Record 49 of Set 2 | lotoshino
# Processing Record 50 of Set 2 | khatanga
# Processing Record 1 of Set 3 | bonthe
# Processing Record 2 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 3 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 3 | praia
# Processing Record 5 of Set 3 | manaure
# Processing Record 6 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 3 | hay river
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | lompoc
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | nouadhibou
# Processing Record 13 of Set 3 | saint-joseph
# Processing Record 14 of Set 3 | korla
# Processing Record 15 of Set 3 | bac lieu
# Processing Record 16 of Set 3 | buraydah
# Processing Record 17 of Set 3 | jiuquan
# Processing Record 18 of Set 3 | tatarsk
# Processing Record 19 of Set 3 | pacific grove
# Processing Record 20 of Set 3 | yar-sale
# Processing Record 21 of Set 3 | the valley
# Processing Record 22 of Set 3 | great yarmouth
# Processing Record 23 of Set 3 | tiksi
# Processing Record 24 of Set 3 | mataura
# Processing Record 25 of Set 3 | marawi
# Processing Record 26 of Set 3 | honiara
# Processing Record 27 of Set 3 | novoagansk
# Processing Record 28 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 3 | ilulissat
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | laguna
# Processing Record 32 of Set 3 | litovko
# Processing Record 33 of Set 3 | labuhan
# Processing Record 34 of Set 3 | grand-lahou
# Processing Record 35 of Set 3 | zhigansk
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | olive branch
# Processing Record 38 of Set 3 | clyde river
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | kahului
# Processing Record 41 of Set 3 | trincomalee
# Processing Record 42 of Set 3 | chegdomyn
# Processing Record 43 of Set 3 | ostrovnoy
# Processing Record 44 of Set 3 | lao cai
# Processing Record 45 of Set 3 | nizhniy odes
# Processing Record 46 of Set 3 | shar
# Processing Record 47 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 3 | tuktoyaktuk
# Processing Record 49 of Set 3 | paraopeba
# Processing Record 50 of Set 3 | broome
# Processing Record 1 of Set 4 | ancud
# Processing Record 2 of Set 4 | puerto ayora
# Processing Record 3 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 4 | pangnirtung
# Processing Record 5 of Set 4 | ribeira grande
# Processing Record 6 of Set 4 | garissa
# Processing Record 7 of Set 4 | ahuimanu
# Processing Record 8 of Set 4 | touros
# Processing Record 9 of Set 4 | castro
# Processing Record 10 of Set 4 | mandalgovi
# Processing Record 11 of Set 4 | sao filipe
# Processing Record 12 of Set 4 | la ronge
# Processing Record 13 of Set 4 | cabo san lucas
# Processing Record 14 of Set 4 | kyren
# Processing Record 15 of Set 4 | falkenberg
# Processing Record 16 of Set 4 | phayao
# Processing Record 17 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 4 | moose factory
# Processing Record 19 of Set 4 | hualmay
# Processing Record 20 of Set 4 | jijiga
# Processing Record 21 of Set 4 | lianran
# Processing Record 22 of Set 4 | adrar
# Processing Record 23 of Set 4 | praia da vitoria
# Processing Record 24 of Set 4 | never
# Processing Record 25 of Set 4 | raudeberg
# Processing Record 26 of Set 4 | nexo
# Processing Record 27 of Set 4 | batemans bay
# Processing Record 28 of Set 4 | constitucion
# Processing Record 29 of Set 4 | chuy
# Processing Record 30 of Set 4 | alofi
# Processing Record 31 of Set 4 | kampot
# Processing Record 32 of Set 4 | teahupoo
# Processing Record 33 of Set 4 | nantucket
# Processing Record 34 of Set 4 | champerico
# Processing Record 35 of Set 4 | narsaq
# Processing Record 36 of Set 4 | mahebourg
# Processing Record 37 of Set 4 | kyshtovka
# Processing Record 38 of Set 4 | westport
# Processing Record 39 of Set 4 | buala
# Processing Record 40 of Set 4 | chokurdakh
# Processing Record 41 of Set 4 | avarua
# Processing Record 42 of Set 4 | jasper
# Processing Record 43 of Set 4 | bredasdorp
# Processing Record 44 of Set 4 | sidi ali
# Processing Record 45 of Set 4 | oranjestad
# Processing Record 46 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 4 | xai-xai
# Processing Record 48 of Set 4 | bathsheba
# Processing Record 49 of Set 4 | irbit
# Processing Record 50 of Set 4 | vestmannaeyjar
# Processing Record 1 of Set 5 | saldanha
# Processing Record 2 of Set 5 | itarema
# Processing Record 3 of Set 5 | port augusta
# Processing Record 4 of Set 5 | vila franca do campo
# Processing Record 5 of Set 5 | lamu
# Processing Record 6 of Set 5 | cumpas
# Processing Record 7 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 5 | camacha
# Processing Record 9 of Set 5 | nicoya
# Processing Record 10 of Set 5 | bengkulu
# Processing Record 11 of Set 5 | arcata
# Processing Record 12 of Set 5 | perdoes
# Processing Record 13 of Set 5 | acapulco
# Processing Record 14 of Set 5 | mingaora
# Processing Record 15 of Set 5 | chadiza
# Processing Record 16 of Set 5 | san andres
# Processing Record 17 of Set 5 | sangin
# Processing Record 18 of Set 5 | benghazi
# Processing Record 19 of Set 5 | punta alta
# Processing Record 20 of Set 5 | pisco
# Processing Record 21 of Set 5 | solnechnyy
# Processing Record 22 of Set 5 | moissala
# Processing Record 23 of Set 5 | sedkyrkeshch
# Processing Record 24 of Set 5 | cabedelo
# Processing Record 25 of Set 5 | srednekolymsk
# Processing Record 26 of Set 5 | san vicente
# Processing Record 27 of Set 5 | tucurui
# Processing Record 28 of Set 5 | rock springs
# Processing Record 29 of Set 5 | canala
# Processing Record 30 of Set 5 | nikolskoye
# Processing Record 31 of Set 5 | atasu
# Processing Record 32 of Set 5 | valparaiso
# Processing Record 33 of Set 5 | kara-tyube
# Processing Record 34 of Set 5 | noumea
# Processing Record 35 of Set 5 | sitka
# Processing Record 36 of Set 5 | bafq
# Processing Record 37 of Set 5 | araouane
# Processing Record 38 of Set 5 | abu dhabi
# Processing Record 39 of Set 5 | pindi bhattian
# Processing Record 40 of Set 5 | poum
# Processing Record 41 of Set 5 | tefe
# Processing Record 42 of Set 5 | tomatlan
# Processing Record 43 of Set 5 | severo-kurilsk
# Processing Record 44 of Set 5 | guerrero negro
# Processing Record 45 of Set 5 | huarmey
# Processing Record 46 of Set 5 | izhma
# Processing Record 47 of Set 5 | bluffton
# Processing Record 48 of Set 5 | hasaki
# Processing Record 49 of Set 5 | novorzhev
# Processing Record 50 of Set 5 | henties bay
# Processing Record 1 of Set 6 | moundsville
# Processing Record 2 of Set 6 | zarubino
# Processing Record 3 of Set 6 | hami
# Processing Record 4 of Set 6 | abbeville
# Processing Record 5 of Set 6 | new norfolk
# Processing Record 6 of Set 6 | padang
# Processing Record 7 of Set 6 | guiyang
# Processing Record 8 of Set 6 | vanimo
# Processing Record 9 of Set 6 | marquette
# Processing Record 10 of Set 6 | lorengau
# Processing Record 11 of Set 6 | voyvozh
# Processing Record 12 of Set 6 | pevek
# Processing Record 13 of Set 6 | lata
# Processing Record 14 of Set 6 | albion
# Processing Record 15 of Set 6 | ambilobe
# Processing Record 16 of Set 6 | sorland
# Processing Record 17 of Set 6 | alyangula
# Processing Record 18 of Set 6 | mesto albrechtice
# Processing Record 19 of Set 6 | ulladulla
# Processing Record 20 of Set 6 | moyale
# Processing Record 21 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 6 | christchurch
# Processing Record 23 of Set 6 | rabo de peixe
# Processing Record 24 of Set 6 | karakendzha
# City not found. Skipping...
# Processing Record 25 of Set 6 | koraput
# Processing Record 26 of Set 6 | taltal
# Processing Record 27 of Set 6 | mao
# Processing Record 28 of Set 6 | olavarria
# Processing Record 29 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 6 | brae
# Processing Record 31 of Set 6 | zhovtneve
# Processing Record 32 of Set 6 | aquiraz
# Processing Record 33 of Set 6 | hagenow
# Processing Record 34 of Set 6 | pishin
# Processing Record 35 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 6 | dudinka
# Processing Record 37 of Set 6 | magadan
# Processing Record 38 of Set 6 | airai
# Processing Record 39 of Set 6 | amuntai
# Processing Record 40 of Set 6 | banmo
# City not found. Skipping...
# Processing Record 41 of Set 6 | iqaluit
# Processing Record 42 of Set 6 | san quintin
# Processing Record 43 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 6 | mirabad
# Processing Record 45 of Set 6 | ketchikan
# Processing Record 46 of Set 6 | mount isa
# Processing Record 47 of Set 6 | balsas
# Processing Record 48 of Set 6 | clinton
# Processing Record 49 of Set 6 | piopio
# Processing Record 50 of Set 6 | witu
# Processing Record 1 of Set 7 | ponta do sol
# Processing Record 2 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 3 of Set 7 | la asuncion
# Processing Record 4 of Set 7 | taree
# Processing Record 5 of Set 7 | iquique
# Processing Record 6 of Set 7 | cidreira
# Processing Record 7 of Set 7 | kavieng
# Processing Record 8 of Set 7 | babu
# Processing Record 9 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 7 | shakiso
# Processing Record 11 of Set 7 | amalapuram
# Processing Record 12 of Set 7 | dorna
# Processing Record 13 of Set 7 | turukhansk
# Processing Record 14 of Set 7 | shaunavon
# Processing Record 15 of Set 7 | miandoab
# Processing Record 16 of Set 7 | san luis
# Processing Record 17 of Set 7 | honjo
# Processing Record 18 of Set 7 | panguna
# Processing Record 19 of Set 7 | sankheda
# Processing Record 20 of Set 7 | tura
# Processing Record 21 of Set 7 | comodoro rivadavia
# Processing Record 22 of Set 7 | mongar
# Processing Record 23 of Set 7 | hervey bay
# Processing Record 24 of Set 7 | zabid
# Processing Record 25 of Set 7 | wamba
# Processing Record 26 of Set 7 | togur
# Processing Record 27 of Set 7 | dikson
# Processing Record 28 of Set 7 | dingle
# Processing Record 29 of Set 7 | necochea
# Processing Record 30 of Set 7 | quatre cocos
# Processing Record 31 of Set 7 | tasiilaq
# Processing Record 32 of Set 7 | omsukchan
# Processing Record 33 of Set 7 | aleksandrov gay
# Processing Record 34 of Set 7 | bonavista
# Processing Record 35 of Set 7 | banda aceh
# Processing Record 36 of Set 7 | senanga
# Processing Record 37 of Set 7 | butaritari
# Processing Record 38 of Set 7 | zambezi
# Processing Record 39 of Set 7 | bubaque
# Processing Record 40 of Set 7 | aklavik
# Processing Record 41 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 42 of Set 7 | san cristobal
# Processing Record 43 of Set 7 | bambanglipuro
# Processing Record 44 of Set 7 | pitimbu
# Processing Record 45 of Set 7 | iquitos
# Processing Record 46 of Set 7 | zvishavane
# Processing Record 47 of Set 7 | farah
# Processing Record 48 of Set 7 | marau
# Processing Record 49 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 7 | abu kamal
# Processing Record 1 of Set 8 | soyo
# Processing Record 2 of Set 8 | altamira
# Processing Record 3 of Set 8 | hrinova
# Processing Record 4 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 8 | upernavik
# Processing Record 6 of Set 8 | paralimni
# Processing Record 7 of Set 8 | minab
# Processing Record 8 of Set 8 | yuzhnyy
# Processing Record 9 of Set 8 | saint-pierre
# Processing Record 10 of Set 8 | saint-philippe
# Processing Record 11 of Set 8 | bollnas
# Processing Record 12 of Set 8 | lucea
# Processing Record 13 of Set 8 | hammerfest
# Processing Record 14 of Set 8 | nemuro
# Processing Record 15 of Set 8 | abha
# Processing Record 16 of Set 8 | alice springs
# Processing Record 17 of Set 8 | viedma
# Processing Record 18 of Set 8 | iracoubo
# Processing Record 19 of Set 8 | port-gentil
# Processing Record 20 of Set 8 | shirvan
# Processing Record 21 of Set 8 | channel-port aux basques
# Processing Record 22 of Set 8 | walvis bay
# Processing Record 23 of Set 8 | sao marcos
# Processing Record 24 of Set 8 | sola
# Processing Record 25 of Set 8 | port-cartier
# Processing Record 26 of Set 8 | fairbanks
# Processing Record 27 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 8 | longyearbyen
# Processing Record 29 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 30 of Set 8 | kjopsvik
# Processing Record 31 of Set 8 | venice
# Processing Record 32 of Set 8 | los banos
# Processing Record 33 of Set 8 | faya
# Processing Record 34 of Set 8 | san patricio
# Processing Record 35 of Set 8 | carlyle
# Processing Record 36 of Set 8 | meiktila
# Processing Record 37 of Set 8 | loreto
# Processing Record 38 of Set 8 | bilma
# Processing Record 39 of Set 8 | santa marta
# Processing Record 40 of Set 8 | juba
# Processing Record 41 of Set 8 | kawalu
# Processing Record 42 of Set 8 | tiznit
# Processing Record 43 of Set 8 | hamilton
# Processing Record 44 of Set 8 | bandarbeyla
# Processing Record 45 of Set 8 | qaqortoq
# Processing Record 46 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 47 of Set 8 | boffa
# Processing Record 48 of Set 8 | lae
# Processing Record 49 of Set 8 | dunedin
# Processing Record 50 of Set 8 | lashio
# Processing Record 1 of Set 9 | udachnyy
# Processing Record 2 of Set 9 | opobo
# City not found. Skipping...
# Processing Record 3 of Set 9 | coahuayana
# Processing Record 4 of Set 9 | price
# Processing Record 5 of Set 9 | atikokan
# Processing Record 6 of Set 9 | raga
# Processing Record 7 of Set 9 | prince albert
# Processing Record 8 of Set 9 | magelang
# Processing Record 9 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 10 of Set 9 | orlik
# Processing Record 11 of Set 9 | kulhudhuffushi
# Processing Record 12 of Set 9 | norman wells
# Processing Record 13 of Set 9 | seguela
# Processing Record 14 of Set 9 | jinji
# Processing Record 15 of Set 9 | uyuni
# Processing Record 16 of Set 9 | jacareacanga
# Processing Record 17 of Set 9 | aksarka
# Processing Record 18 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 9 | phangnga
# Processing Record 20 of Set 9 | katsuura
# Processing Record 21 of Set 9 | kodinsk
# Processing Record 22 of Set 9 | jakoruda
# City not found. Skipping...
# Processing Record 23 of Set 9 | corralillo
# Processing Record 24 of Set 9 | tateyama
# Processing Record 25 of Set 9 | nha trang
# Processing Record 26 of Set 9 | amarante do maranhao
# Processing Record 27 of Set 9 | saint-augustin
# Processing Record 28 of Set 9 | vila velha
# Processing Record 29 of Set 9 | male
# Processing Record 30 of Set 9 | joao pinheiro
# Processing Record 31 of Set 9 | carroll
# Processing Record 32 of Set 9 | mwinilunga
# Processing Record 33 of Set 9 | deniliquin
# Processing Record 34 of Set 9 | montlucon
# Processing Record 35 of Set 9 | chilca
# Processing Record 36 of Set 9 | guelengdeng
# City not found. Skipping...
# Processing Record 37 of Set 9 | cavalcante
# Processing Record 38 of Set 9 | port hedland
# Processing Record 39 of Set 9 | gombong
# Processing Record 40 of Set 9 | goundam
# Processing Record 41 of Set 9 | kaura namoda
# Processing Record 42 of Set 9 | atambua
# Processing Record 43 of Set 9 | baherden
# Processing Record 44 of Set 9 | arua
# Processing Record 45 of Set 9 | sao jose da coroa grande
# Processing Record 46 of Set 9 | rafaela
# Processing Record 47 of Set 9 | bad sankt leonhard
# City not found. Skipping...
# Processing Record 48 of Set 9 | olafsvik
# Processing Record 49 of Set 9 | pulgaon
# Processing Record 50 of Set 9 | honningsvag
# Processing Record 1 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 10 | numan
# Processing Record 3 of Set 10 | flin flon
# Processing Record 4 of Set 10 | leningradskiy
# Processing Record 5 of Set 10 | northam
# Processing Record 6 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 10 | pizarro
# Processing Record 8 of Set 10 | santa isabel
# Processing Record 9 of Set 10 | chapais
# Processing Record 10 of Set 10 | shitanjing
# Processing Record 11 of Set 10 | indiana
# Processing Record 12 of Set 10 | yei
# Processing Record 13 of Set 10 | angouleme
# Processing Record 14 of Set 10 | gushikawa
# Processing Record 15 of Set 10 | toyooka
# Processing Record 16 of Set 10 | manokwari
# Processing Record 17 of Set 10 | dabat
# Processing Record 18 of Set 10 | ixtapa
# Processing Record 19 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 10 | forssa
# Processing Record 21 of Set 10 | mandera
# Processing Record 22 of Set 10 | bell ville
# Processing Record 23 of Set 10 | marystown
# Processing Record 24 of Set 10 | trelew
# Processing Record 25 of Set 10 | yaring
# Processing Record 26 of Set 10 | makakilo city
# Processing Record 27 of Set 10 | mwingi
# Processing Record 28 of Set 10 | qujing
# Processing Record 29 of Set 10 | fokino
# Processing Record 30 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 31 of Set 10 | monte cristi
# City not found. Skipping...
# Processing Record 32 of Set 10 | pengcheng
# Processing Record 33 of Set 10 | navirai
# Processing Record 34 of Set 10 | taoudenni
# Processing Record 35 of Set 10 | luau
# Processing Record 36 of Set 10 | kavaratti
# Processing Record 37 of Set 10 | houma
# Processing Record 38 of Set 10 | ayagoz
# Processing Record 39 of Set 10 | buin
# Processing Record 40 of Set 10 | ostroda
# Processing Record 41 of Set 10 | buluang
# Processing Record 42 of Set 10 | cranbrook
# Processing Record 43 of Set 10 | uray
# Processing Record 44 of Set 10 | talara
# Processing Record 45 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 46 of Set 10 | mayumba
# Processing Record 47 of Set 10 | turiacu
# Processing Record 48 of Set 10 | promysla
# City not found. Skipping...
# Processing Record 49 of Set 10 | wanaka
# Processing Record 50 of Set 10 | gat
# Processing Record 1 of Set 11 | southbridge
# Processing Record 2 of Set 11 | colesberg
# Processing Record 3 of Set 11 | rincon
# Processing Record 4 of Set 11 | dobruska
# Processing Record 5 of Set 11 | rawson
# Processing Record 6 of Set 11 | acarau
# Processing Record 7 of Set 11 | belaya gora
# Processing Record 8 of Set 11 | ola
# Processing Record 9 of Set 11 | erzin
# Processing Record 10 of Set 11 | oak harbor
# Processing Record 11 of Set 11 | kholmogory
# Processing Record 12 of Set 11 | whitehorse
# Processing Record 13 of Set 11 | chicama
# Processing Record 14 of Set 11 | lasa
# Processing Record 15 of Set 11 | daru
# Processing Record 16 of Set 11 | shimoda
# Processing Record 17 of Set 11 | manzanillo
# Processing Record 18 of Set 11 | eureka
# Processing Record 19 of Set 11 | wakkanai
# Processing Record 20 of Set 11 | asau
# Processing Record 21 of Set 11 | mokokchung
# Processing Record 22 of Set 11 | santa cruz de la palma
# Processing Record 23 of Set 11 | havre-saint-pierre
# Processing Record 24 of Set 11 | menzelinsk
# Processing Record 25 of Set 11 | ilinskiy
# Processing Record 26 of Set 11 | santa vitoria do palmar
# Processing Record 27 of Set 11 | waitati
# Processing Record 28 of Set 11 | luderitz
# Processing Record 29 of Set 11 | civitanova marche
# Processing Record 30 of Set 11 | saint-georges
# Processing Record 31 of Set 11 | prosperous
# Processing Record 32 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 33 of Set 11 | alta floresta
# Processing Record 34 of Set 11 | mogzon
# Processing Record 35 of Set 11 | alexandria
# Processing Record 36 of Set 11 | staryy nadym
# Processing Record 37 of Set 11 | constantine
# Processing Record 38 of Set 11 | port blair
# Processing Record 39 of Set 11 | mega
# Processing Record 40 of Set 11 | sayyan
# Processing Record 41 of Set 11 | seoul
# Processing Record 42 of Set 11 | samarai
# Processing Record 43 of Set 11 | zhuanghe
# Processing Record 44 of Set 11 | kilindoni
# Processing Record 45 of Set 11 | bara
# Processing Record 46 of Set 11 | bilokurakyne
# Processing Record 47 of Set 11 | rio gallegos
# Processing Record 48 of Set 11 | tupik
# Processing Record 49 of Set 11 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 50 of Set 11 | mahanje
# Processing Record 1 of Set 12 | chernyshevskiy
# Processing Record 2 of Set 12 | teguise
# Processing Record 3 of Set 12 | tautira
# Processing Record 4 of Set 12 | saint-louis
# Processing Record 5 of Set 12 | filingue
# Processing Record 6 of Set 12 | namibe
# Processing Record 7 of Set 12 | ereymentau
# Processing Record 8 of Set 12 | karla
# Processing Record 9 of Set 12 | morant bay
# Processing Record 10 of Set 12 | kalmunai
# Processing Record 11 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 12 of Set 12 | yenagoa
# Processing Record 13 of Set 12 | khasan
# Processing Record 14 of Set 12 | aberdeen
# Processing Record 15 of Set 12 | elizabeth city
# Processing Record 16 of Set 12 | los llanos de aridane
# Processing Record 17 of Set 12 | warrnambool
# Processing Record 18 of Set 12 | launceston
# Processing Record 19 of Set 12 | bolivar
# Processing Record 20 of Set 12 | podyuga
# Processing Record 21 of Set 12 | bosconia
# Processing Record 22 of Set 12 | talnakh
# Processing Record 23 of Set 12 | mayo
# Processing Record 24 of Set 12 | nuuk
# Processing Record 25 of Set 12 | karasjok
# Processing Record 26 of Set 12 | souillac
# Processing Record 27 of Set 12 | kamaishi
# Processing Record 28 of Set 12 | waipawa
# Processing Record 29 of Set 12 | carman
# Processing Record 30 of Set 12 | pringsewu
# Processing Record 31 of Set 12 | puerto escondido
# Processing Record 32 of Set 12 | naze
# Processing Record 33 of Set 12 | antalaha
# Processing Record 34 of Set 12 | arenys de mar
# Processing Record 35 of Set 12 | myitkyina
# Processing Record 36 of Set 12 | podor
# Processing Record 37 of Set 12 | deputatskiy
# Processing Record 38 of Set 12 | lovozero
# Processing Record 39 of Set 12 | carlsbad
# Processing Record 40 of Set 12 | saint anthony
# Processing Record 41 of Set 12 | margate
# Processing Record 42 of Set 12 | lima
# Processing Record 43 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 12 | iwanai
# Processing Record 45 of Set 12 | ulaangom
# Processing Record 46 of Set 12 | sept-iles
# Processing Record 47 of Set 12 | cockburn town
# Processing Record 48 of Set 12 | miyako
# Processing Record 49 of Set 12 | bronnoysund
# Processing Record 50 of Set 12 | solwezi
# Processing Record 1 of Set 13 | katete
# Processing Record 2 of Set 13 | isabela
# Processing Record 3 of Set 13 | omboue
# Processing Record 4 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 5 of Set 13 | corinto
# Processing Record 6 of Set 13 | sandnessjoen
# Processing Record 7 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 8 of Set 13 | gorontalo
# Processing Record 9 of Set 13 | vityazevo
# Processing Record 10 of Set 13 | upata
# Processing Record 11 of Set 13 | banepa
# Processing Record 12 of Set 13 | verkhnyaya toyma
# Processing Record 13 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 14 of Set 13 | turbat
# Processing Record 15 of Set 13 | celestun
# Processing Record 16 of Set 13 | anadyr
# Processing Record 17 of Set 13 | nioki
# Processing Record 18 of Set 13 | visby
# Processing Record 19 of Set 13 | surt
# Processing Record 20 of Set 13 | buribay
# Processing Record 21 of Set 13 | reconquista
# Processing Record 22 of Set 13 | casablanca
# Processing Record 23 of Set 13 | centralia
# Processing Record 24 of Set 13 | fujinomiya
# Processing Record 25 of Set 13 | akcakoca
# Processing Record 26 of Set 13 | metu
# Processing Record 27 of Set 13 | hobyo
# Processing Record 28 of Set 13 | ihosy
# Processing Record 29 of Set 13 | santa isabel do para
# Processing Record 30 of Set 13 | ouango
# Processing Record 31 of Set 13 | mildura
# Processing Record 32 of Set 13 | les escoumins
# Processing Record 33 of Set 13 | sur
# Processing Record 34 of Set 13 | muswellbrook
# Processing Record 35 of Set 13 | jalu
# Processing Record 36 of Set 13 | cheney
# Processing Record 37 of Set 13 | lahaina
# Processing Record 38 of Set 13 | agdas
# Processing Record 39 of Set 13 | karratha
# Processing Record 40 of Set 13 | grand gaube
# Processing Record 41 of Set 13 | malanje
# Processing Record 42 of Set 13 | starogard gdanski
# Processing Record 43 of Set 13 | rio grande
# Processing Record 44 of Set 13 | manbij
# Processing Record 45 of Set 13 | yeppoon
# Processing Record 46 of Set 13 | kontagora
# Processing Record 47 of Set 13 | lahij
# Processing Record 48 of Set 13 | broken hill
# Processing Record 49 of Set 13 | kargasok
# Processing Record 50 of Set 13 | okha
# Processing Record 1 of Set 14 | nuevo progreso
# Processing Record 2 of Set 14 | hrodna
# Processing Record 3 of Set 14 | shingu
# Processing Record 4 of Set 14 | krasnyy chikoy
# Processing Record 5 of Set 14 | ilhabela
# Processing Record 6 of Set 14 | guanica
# Processing Record 7 of Set 14 | ust-ishim
# Processing Record 8 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 14 | victoria point
# Processing Record 10 of Set 14 | newport
# Processing Record 11 of Set 14 | paranaiba
# Processing Record 12 of Set 14 | komatipoort
# Processing Record 13 of Set 14 | namatanai
# Processing Record 14 of Set 14 | muhos
# Processing Record 15 of Set 14 | jieshou
# Processing Record 16 of Set 14 | aybak
# City not found. Skipping...
# Processing Record 17 of Set 14 | salcedo
# Processing Record 18 of Set 14 | bakel
# Processing Record 19 of Set 14 | parczew
# Processing Record 20 of Set 14 | duldurga
# Processing Record 21 of Set 14 | nichinan
# Processing Record 22 of Set 14 | porto novo
# Processing Record 23 of Set 14 | kusa
# Processing Record 24 of Set 14 | we
# City not found. Skipping...
# Processing Record 25 of Set 14 | santander
# Processing Record 26 of Set 14 | green river
# Processing Record 27 of Set 14 | tome-acu
# City not found. Skipping...
# Processing Record 28 of Set 14 | codrington
# Processing Record 29 of Set 14 | balykshi
# Processing Record 30 of Set 14 | boundiali
# Processing Record 31 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 32 of Set 14 | zwedru
# Processing Record 33 of Set 14 | rocha
# Processing Record 34 of Set 14 | mana
# Processing Record 35 of Set 14 | eydhafushi
# Processing Record 36 of Set 14 | avera
# Processing Record 37 of Set 14 | tigil
# Processing Record 38 of Set 14 | astana
# Processing Record 39 of Set 14 | martinez
# Processing Record 40 of Set 14 | lingao
# Processing Record 41 of Set 14 | hemnesberget
# Processing Record 42 of Set 14 | sarankhola
# Processing Record 43 of Set 14 | cruzeiro do sul
# Processing Record 44 of Set 14 | itaberai
# Processing Record 45 of Set 14 | gao
# Processing Record 46 of Set 14 | fuquay-varina
# Processing Record 47 of Set 14 | matagami
# Processing Record 48 of Set 14 | ambulu
# Processing Record 49 of Set 14 | waiuku
# Processing Record 50 of Set 14 | villa bruzual
# Processing Record 1 of Set 15 | kutum
# Processing Record 2 of Set 15 | pucallpa
# Processing Record 3 of Set 15 | zyryanka
# Processing Record 4 of Set 15 | roma
# Processing Record 5 of Set 15 | wajir
# Processing Record 6 of Set 15 | chumikan
# Processing Record 7 of Set 15 | kadoma
# Processing Record 8 of Set 15 | alappuzha
# Processing Record 9 of Set 15 | el campo
# Processing Record 10 of Set 15 | mafinga
# Processing Record 11 of Set 15 | idritsa
# Processing Record 12 of Set 15 | beira
# Processing Record 13 of Set 15 | kathmandu
# Processing Record 14 of Set 15 | boyolangu
# Processing Record 15 of Set 15 | concepcion del oro
# Processing Record 16 of Set 15 | ahipara
# Processing Record 17 of Set 15 | kazachinskoye
# Processing Record 18 of Set 15 | emporia
# Processing Record 19 of Set 15 | harbour breton
# Processing Record 20 of Set 15 | appleton
# Processing Record 21 of Set 15 | blagodatnoye
# Processing Record 22 of Set 15 | paamiut
# Processing Record 23 of Set 15 | kudahuvadhoo
# Processing Record 24 of Set 15 | santa rosa
# Processing Record 25 of Set 15 | yaan
# Processing Record 26 of Set 15 | hengyang
# Processing Record 27 of Set 15 | pochutla
# Processing Record 28 of Set 15 | urucui
# Processing Record 29 of Set 15 | burhaniye
# Processing Record 30 of Set 15 | sinnamary
# Processing Record 31 of Set 15 | nardaran
# Processing Record 32 of Set 15 | oistins
# Processing Record 33 of Set 15 | patacamaya
# Processing Record 34 of Set 15 | jieshi
# Processing Record 35 of Set 15 | bor
# Processing Record 36 of Set 15 | tukrah
# Processing Record 37 of Set 15 | najran
# Processing Record 38 of Set 15 | natchitoches
# Processing Record 39 of Set 15 | husavik
# Processing Record 40 of Set 15 | puerto ayacucho
# Processing Record 41 of Set 15 | khorixas
# Processing Record 42 of Set 15 | manono
# Processing Record 43 of Set 15 | salinas
# Processing Record 44 of Set 15 | sakakah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Barrow  71.2906 -156.7887     33.82        80          75
# 1        Jamestown  42.0970  -79.2353     73.04        54           0
# 2            Luwuk  -0.9516  122.7875     84.85        75          32
# 3            Vardo  70.3705   31.1107     37.38        81         100
# 4          Taksimo  56.3444  114.8794     56.93        46          82
# 5  Bambous Virieux -20.3428   57.7575     73.65        88          40
# 6     Punta Arenas -53.1500  -70.9167     42.91        81           0
# 7           Albany  42.6001  -73.9662     69.39        93         100
# 8          Rikitea -23.1203 -134.9692     77.04        71          27
# 9    Sioux Lookout  50.1001  -91.9170     44.67        76         100
#
#    Wind Speed Country Current Description
# 0        9.22      US       broken clouds
# 1        3.44      US           clear sky
# 2        2.28      ID    scattered clouds
# 3        9.22      NO     overcast clouds
# 4       11.65      RU       broken clouds
# 5       11.50      MU       moderate rain
# 6        5.75      CL           clear sky
# 7        4.09      US     overcast clouds
# 8       18.68      PF    scattered clouds
# 9       11.50      CA     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Barrow      US  71.2906 -156.7887     33.82        80          75
# 1        Jamestown      US  42.0970  -79.2353     73.04        54           0
# 2            Luwuk      ID  -0.9516  122.7875     84.85        75          32
# 3            Vardo      NO  70.3705   31.1107     37.38        81         100
# 4          Taksimo      RU  56.3444  114.8794     56.93        46          82
# 5  Bambous Virieux      MU -20.3428   57.7575     73.65        88          40
# 6     Punta Arenas      CL -53.1500  -70.9167     42.91        81           0
# 7           Albany      US  42.6001  -73.9662     69.39        93         100
# 8          Rikitea      PF -23.1203 -134.9692     77.04        71          27
# 9    Sioux Lookout      CA  50.1001  -91.9170     44.67        76         100
#
#    Wind Speed Current Description
# 0        9.22       broken clouds
# 1        3.44           clear sky
# 2        2.28    scattered clouds
# 3        9.22     overcast clouds
# 4       11.65       broken clouds
# 5       11.50       moderate rain
# 6        5.75           clear sky
# 7        4.09     overcast clouds
# 8       18.68    scattered clouds
# 9       11.50     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
